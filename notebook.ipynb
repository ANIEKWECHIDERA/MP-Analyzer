# %%
import pandas as pd
pd.set_option('display.max_columns', None)

df = pd.read_excel(r"C:\Users\chide\Downloads\testMpa.xlsx")
df
# Out:
#     CODE          BRANCHES          ZONES      BRANCH HEAD
# 0    NaN               NaN            NaN              NaN  \
# 1    NaN          BRANCHES          ZONES         BRANCHES
# 2   20.0             Ikoyi        Ikoyi 1  OSAIGBOVO HENRY
# 3  302.0  Ozumba Mbadiwe 2        Ikoyi 1     IDIKA LINDA
# 4  369.0     Admiralty way        Ikoyi 1       UJU NKECHI
# 5    NaN               NaN  Ikoyi 1 Total              NaN
#
#            ZONAL HEAD  REGION LEVEL LINE ED Age                  (Y-M)
# 0                 NaN     NaN   NaN     NaN                        NaN  \
# 1          ZONAL HEAD  REGION   NaN     NaN                        NaN
# 2  Mobolanle Akintoye   Lagos   AGM      AN               28    -    0
# 3  Mobolanle Akintoye   Lagos   AGM      AN              15    -    10
# 4  Mobolanle Akintoye   Lagos   AGM      AN                7    -    9
# 5                 NaN     NaN   NaN     NaN                        NaN
#
# ...
